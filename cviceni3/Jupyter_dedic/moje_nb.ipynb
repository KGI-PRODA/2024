# %% [markdown]
# ### Nápis 3. urovně

# %% [markdown]
# ### Algoritmus pro zařazování tůní <a id = "nadpis" ></a>
# 1, Nahrajeme si LAS data tůněk
# 2, specifikujeme si tvar tůněk a rozdělíme do n
#  kategorii
# **3, vytvoříme algoritmus** pro zařazování tůněk do kategorií *dle* specifikací
# 4, naučíme algoritmus zařazovat tůňky do kategorií tím, že mu budeme dávat spousty LAS dat tůněk

# %% [markdown]
# ***

# %% [markdown]
# Moje úžasná stránka **http://dedicjan.cz/**
# Link v rámci tohoto notebooku [nadpis](#nadpis) a fotka ![maskoti_spodek.jpg](attachment:maskoti_spodek.jpg)

# %%
print("Hello world!")
# Out:
# Hello world!

# %%
a = 2
b = 3
c = a + b
print(c)
print(a)
# Out:
# 5
# 2

# %%
d = 4.4
text = "polygon"
check = True
Olomouc = (17, 45)
my_list = ["apple", "banana", "orange"]
